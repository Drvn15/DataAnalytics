# %%
import pandas as pd

# %%
df= pd.read_csv ("Sleep_health_and_lifestyle_dataset.csv")

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep_Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality_of_Sleep Physical_Activity_Level  Stress_Level BMI_Category  \
# 0                 6.0                      42             6   Overweight
# ...

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep_Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality_of_Sleep Physical_Activity_Level  Stress_Level BMI_Category  \
# 0               6.0                      42             6   Overweight
# 1               6.0                      60             8       Normal
# 2               6.0                       0             8       Normal
# 3               0.0                      30             8        Obese
# 4               4.0                      30             8        Obese
#
#   Blood_Pressure  Heart_Rate  Daily_Steps Sleep_Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep_Duration  Quality_of_Sleep  \
# 369        370  Female   59      Nurse             8.1               9.0
# 370        371  Female   59      Nurse             8.0               9.0
# 371        372  Female   59      Nurse             8.1               9.0
# 372        373  Female   59      Nurse             8.1               9.0
# 373        374  Female   59      Nurse             8.1               9.0
#
#     Physical_Activity_Level  Stress_Level BMI_Category Blood_Pressure  \
# 369                      75             3   Overweight         140/95
# 370                      75             3   Overweight         140/95
# 371                      75             3   Overweight         140/95
# 372                      75             3   Overweight         140/95
# 373                      75             3   Overweight         140/95
#
#      Heart_Rate  Daily_Steps Sleep_Disorder
# 369          68         7000    Sleep Apnea
# ...

# %%
df.shape
# Out:
# (374, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep_Duration           374 non-null    float64
#  5   Quality_of_Sleep         373 non-null    float64
#  6   Physical_Activity_Level  372 non-null    object
#  7   Stress_Level             374 non-null    int64
#  8   BMI_Category             374 non-null    object
#  9   Blood_Pressure           374 non-null    object
#  10  Heart_Rate               374 non-null    int64
#  11  Daily_Steps              374 non-null    int64
#  12  Sleep_Disorder           155 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 38.1+ KB

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep_Duration  Quality_of_Sleep  Stress_Level  \
# count  374.000000  374.000000      374.000000        373.000000    374.000000
# mean   187.500000   42.184492        7.132086          7.268097      5.385027
# std    108.108742    8.673133        0.795657          1.353202      1.774526
# min      1.000000   27.000000        5.800000          0.000000      3.000000
# 25%     94.250000   35.250000        6.400000          6.000000      4.000000
# 50%    187.500000   43.000000        7.200000          7.000000      5.000000
# 75%    280.750000   50.000000        7.800000          8.000000      7.000000
# max    374.000000   59.000000        8.500000          9.000000      8.000000
#
#        Heart_Rate   Daily_Steps
# count  374.000000    374.000000
# mean    70.165775   6816.844920
# std      4.135676   1617.915679
# min     65.000000   3000.000000
# 25%     68.000000   5600.000000
# 50%     70.000000   7000.000000
# 75%     72.000000   8000.000000
# ...

# %%
df.Heart_Rate.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.boxplot(df.Heart_Rate)
# Out:
# <Axes: ylabel='Heart_Rate'>

# %%
df = df [df.Heart_Rate<=75]

# %%
df.shape
# Out:
# (350, 13)

# %%
df.Heart_Rate.hist()
# Out:
# <Axes: >

# %%
sns.boxplot(df.Heart_Rate)
# Out:
# <Axes: ylabel='Heart_Rate'>

# %%
import pandas as pd

# %%
df= pd.read_csv ("Sleep_health_and_lifestyle_dataset.csv")

# %%
df=df [['Age','Sleep_Duration','Quality_of_Sleep','Physical_Activity_Level','Stress_Level','Heart_Rate','Daily_Steps']]

# %%
df.shape
# Out:
# (374, 7)

# %%
df.isna().sum()
# Out:
# Age                        0
# Sleep_Duration             0
# Quality_of_Sleep           0
# Physical_Activity_Level    3
# Stress_Level               0
# Heart_Rate                 0
# Daily_Steps                0
# dtype: int64

# %%
df.head(20)
# Out:
#     Age  Sleep_Duration  Quality_of_Sleep  Physical_Activity_Level  \
# 0    27             6.1                 6                     42.0
# 1    28             6.2                 6                     60.0
# 2    28             6.2                 6                     60.0
# 3    28             5.9                 4                     30.0
# 4    28             5.9                 4                     30.0
# 5    28             5.9                 4                      NaN
# 6    29             6.3                 6                     40.0
# 7    29             7.8                 7                     75.0
# 8    29             7.8                 7                     75.0
# 9    29             7.8                 7                     75.0
# 10   29             6.1                 6                     30.0
# 11   29             7.8                 7                      NaN
# 12   29             6.1                 6                     30.0
# ...

# %%
df = df.fillna(df.median())

# %%
df.head(20)
# Out:
#     Age  Sleep_Duration  Quality_of_Sleep  Physical_Activity_Level  \
# 0    27             6.1                 6                     42.0
# 1    28             6.2                 6                     60.0
# 2    28             6.2                 6                     60.0
# 3    28             5.9                 4                     30.0
# 4    28             5.9                 4                     30.0
# 5    28             5.9                 4                     60.0
# 6    29             6.3                 6                     40.0
# 7    29             7.8                 7                     75.0
# 8    29             7.8                 7                     75.0
# 9    29             7.8                 7                     75.0
# 10   29             6.1                 6                     30.0
# 11   29             7.8                 7                     60.0
# 12   29             6.1                 6                     30.0
# ...
